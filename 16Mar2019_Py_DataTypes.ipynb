# %%
name = 'iphone 5s'

# %%
type(name)
# Out:
# str

# %%
print(name)
# Out:
# iphone 5s

# %%
screen_size = 3.56
type(screen_size)
# Out:
# float

# %%
print(screen_size)
# Out:
# 3.56

# %%
num_of_speakers = 1
type(num_of_speakers)
# Out:
# int

# %%
print('I just bought an ' + name +'.')
# Out:
# I just bought an iphone 5s.

# %%
a = 3
b = 2
print(a+b,a-b,a*b,a/b,a**b,a//b)
# Out:
# 5 1 6 1.5 9 1

# %%
is_android = False
type(is_android)
print(is_android == True)
# Out:
# False

# %%
print(is_android == False and num_of_speakers == 1)
# Out:
# True

# %%
if is_android != True:
  print(name + ' does not support android')
  print('This log is written inside the loop')
print('This log is written outside the block')
# Out:
# iphone 5s does not support android
# This log is written inside the loop
# This log is written outside the block

# %%
for i in range(5):
  print(i,i**2)
# Out:
# 0 0
# 1 1
# 2 4
# 3 9
# 4 16

# %%
range?

# %%
i = 0
while i < 5:
  print(i,i**2)
  i += 1 # i  equivaleent i+1
print('outside the block') #functions intro
def print_squaress(stop_value):
  for i in range(stop_value):
    print(i,i**2)
# Out:
# 0 0
# 1 1
# 2 4
# 3 9
# 4 16
# outside the block

# %%
#functions intro
def print_squaress(stop_value):
  for i in range(stop_value):
    print(i,i**2)

# %%
print_squaress(3)
# Out:
# 0 0
# 1 1
# 2 4

# %%
def sum_of_squares(stop_value):
  sum_ = 0
  for i in range(stop_value):
    sum_ += i**2
  return sum_

# %%
sum_of_squares(5)
# Out:
# 30

# %%
def sum_of_squaresss(stop_value,start_value=0):
  '''commented out'''
  for i in range(start_value,stop_value):
    print(i,i**2)

# %%
sum_of_squaresss(5,2)
# Out:
# 2 4
# 3 9
# 4 16

# %%
'''Additional H/W'''
def sum_of_squares(stop_value,start_value = 0):
  sum_ = 0
  for i in range(start_value,stop_value):
    sum_ += i**2
  return sum_

# %%
sum_of_squares(5,3)
# Out:
# 25
